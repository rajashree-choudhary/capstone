# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Reading Food Access data

# %%
food_access = pd.read_csv('../csv_data/food_access_data.csv')

# %%
food_access.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0  0.000000                  0  ...
# 1                  0     181.0  8.341014                  1  ...
# 2                  0       0.0  0.000000                  0  ...
# 3                  0       0.0  0.000000                  0  ...
# 4                  0     181.0  1.681219                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# 1         214.0       888.0      1217.0         5.0         0.0        5.0
# 2         439.0      2576.0       647.0        17.0         5.0       11.0
# 3         904.0      4086.0       193.0        18.0         4.0       11.0
# 4        1126.0      8666.0      1437.0       296.0         9.0       48.0
#
#    TractOMultir  TractHispanic  TractHUNV  TractSNAP
# 0          45.0           44.0        6.0      102.0
# 1          55.0           75.0       89.0      156.0
# 2         117.0           87.0       99.0      172.0
# 3          74.0           85.0       21.0       98.0
# 4         310.0          355.0      230.0      339.0
#
# [5 rows x 147 columns]

# %%
food_access.shape
# Out:
# (72531, 147)

# %%
food_access.describe()
# Out:
#         CensusTract         Urban       Pop2010       OHU2010  \
# count  7.253100e+04  72531.000000  72531.000000  72531.000000
# mean   2.782573e+10      0.760626   4256.739022   1609.191821
# std    1.581647e+10      0.426704   1955.987626    725.676046
# min    1.001020e+09      0.000000      1.000000      0.000000
# 25%    1.212708e+10      1.000000   2899.000000   1108.000000
# 50%    2.712979e+10      1.000000   4011.000000   1525.000000
# 75%    4.103900e+10      1.000000   5330.500000   2021.000000
# max    5.604595e+10      1.000000  37452.000000  16043.000000
#
#        GroupQuartersFlag      NUMGQTRS      PCTGQTRS  LILATracts_1And10  \
# count       72531.000000  72506.000000  72506.000000       72531.000000
# mean            0.007114    110.121549      2.708678           0.128125
# std             0.084046    443.931753      9.570881           0.334231
# min             0.000000      0.000000      0.000000           0.000000
# 25%             0.000000      0.000000      0.000000           0.000000
# 50%             0.000000      7.000000      0.181130           0.000000
# 75%             0.000000     64.000000      1.565217           0.000000
# max             1.000000  19496.000000    100.000000           1.000000
#
#        LILATracts_halfAnd10  LILATracts_1And20  ...  TractSeniors  \
# count          72531.000000       72531.000000  ...  72527.000000
# mean               0.279150           0.112228  ...    555.197113
# std                0.448584           0.315649  ...    351.805391
# min                0.000000           0.000000  ...      0.000000
# 25%                0.000000           0.000000  ...    320.000000
# 50%                0.000000           0.000000  ...    497.000000
# 75%                1.000000           0.000000  ...    718.000000
# max                1.000000           1.000000  ...  17271.000000
#
#          TractWhite    TractBlack    TractAsian    TractNHOPI     TractAIAN  \
# count  72527.000000  72527.000000  72527.000000  72527.000000  72527.000000
# mean    3082.337157    536.756160    202.327685      7.445655     40.152316
# std     1796.364560    889.118109    435.878339     45.186581    177.378696
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     1848.000000     43.000000     17.000000      0.000000      7.000000
# 50%     2914.000000    160.000000     58.000000      1.000000     15.000000
# 75%     4118.000000    610.000000    189.000000      5.000000     33.000000
# max    28983.000000  16804.000000  10485.000000   3491.000000   9009.000000
#
#        TractOMultir  TractHispanic     TractHUNV     TractSNAP
# count  72527.000000   72527.000000  72527.000000  72527.000000
# mean     387.664649     695.979277    143.709736    201.753182
# std      529.349680    1119.472739    232.738869    185.760089
# min        0.000000       0.000000      0.000000      0.000000
# 25%       85.000000      88.000000     36.000000     67.000000
# 50%      186.000000     243.000000     82.000000    152.000000
# 75%      448.000000     751.000000    168.500000    282.000000
# max     8839.000000   15420.000000   6059.000000   2175.000000
#
# [8 rows x 145 columns]

# %%
food_access.isna().sum()
# Out:
# CensusTract      0
# State            0
# County           0
# Urban            0
# Pop2010          0
#                 ..
# TractAIAN        4
# TractOMultir     4
# TractHispanic    4
# TractHUNV        4
# TractSNAP        4
# Length: 147, dtype: int64

# %%
food_access.dtypes
# Out:
# CensusTract        int64
# State             object
# County            object
# Urban              int64
# Pop2010            int64
#                   ...
# TractAIAN        float64
# TractOMultir     float64
# TractHispanic    float64
# TractHUNV        float64
# TractSNAP        float64
# Length: 147, dtype: object

# %%
column_names = food_access.columns.tolist()
print(column_names)
# Out:
# ['CensusTract', 'State', 'County', 'Urban', 'Pop2010', 'OHU2010', 'GroupQuartersFlag', 'NUMGQTRS', 'PCTGQTRS', 'LILATracts_1And10', 'LILATracts_halfAnd10', 'LILATracts_1And20', 'LILATracts_Vehicle', 'HUNVFlag', 'LowIncomeTracts', 'PovertyRate', 'MedianFamilyIncome', 'LA1and10', 'LAhalfand10', 'LA1and20', 'LATracts_half', 'LATracts1', 'LATracts10', 'LATracts20', 'LATractsVehicle_20', 'LAPOP1_10', 'LAPOP05_10', 'LAPOP1_20', 'LALOWI1_10', 'LALOWI05_10', 'LALOWI1_20', 'lapophalf', 'lapophalfshare', 'lalowihalf', 'lalowihalfshare', 'lakidshalf', 'lakidshalfshare', 'laseniorshalf', 'laseniorshalfshare', 'lawhitehalf', 'lawhitehalfshare', 'lablackhalf', 'lablackhalfshare', 'laasianhalf', 'laasianhalfshare', 'lanhopihalf', 'lanhopihalfshare', 'laaianhalf', 'laaianhalfshare', 'laomultirhalf', 'laomultirhalfshare', 'lahisphalf', 'lahisphalfshare', 'lahunvhalf', 'lahunvhalfshare', 'lasnaphalf', 'lasnaphalfshare', 'lapop1', 'lapop1share', 'lalowi1', 'lalowi1share', 'lakids1', 'lakids1share', 'laseniors1', 'laseniors1share', 'lawhite1', 'lawhite1share', 'lablack1', 'lablack1share', 'laasian1', 'laasian1share', 'lanhopi1', 'lanhopi1share', 'laaian1', 'laaian1share', 'laomultir1', 'laomultir1share', 'lahisp1', 'lahisp1share', 'lahunv1', 'lahunv1share', 'lasnap1', 'lasnap1share', 'lapop10', 'lapop10share', 'lalowi10', 'lalowi10share', 'lakids10', 'lakids10share', 'laseniors10', 'laseniors10share', 'lawhite10', 'lawhite10share', 'lablack10', 'lablack10share', 'laasian10', 'laasian10share', 'lanhopi10', 'lanhopi10share', 'laaian10', 'laaian10share', 'laomultir10', 'laomultir10share', 'lahisp10', 'lahisp10share', 'lahunv10', 'lahunv10share', 'lasnap10', 'lasnap10share', 'lapop20', 'lapop20share', 'lalowi20', 'lalowi20share', 'lakids20', 'lakids20share', 'laseniors20', 'laseniors20share', 'lawhite20', 'lawhite20share', 'lablack20', 'lablack20share', 'laasian20', 'laasian20share', 'lanhopi20', 'lanhopi20share', 'laaian20', 'laaian20share', 'laomultir20', 'laomultir20share', 'lahisp20', 'lahisp20share', 'lahunv20', 'lahunv20share', 'lasnap20', 'lasnap20share', 'TractLOWI', 'TractKids', 'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP']

# %%
food_access.set_index('CensusTract', inplace=True)
target_df = food_access[['LILATracts_halfAnd10']]
target_df.head()
# Out:
#              LILATracts_halfAnd10
# CensusTract
# 1001020100                      0
# 1001020200                      1
# 1001020300                      0
# 1001020400                      0
# 1001020500                      0

# %%
target_df.to_csv('../csv_data/target_df.csv')

# %%
food_access = food_access[['OHU2010', 'PovertyRate', 'MedianFamilyIncome', 'TractKids','TractSeniors','TractWhite','TractBlack','TractAsian', 
         'TractNHOPI','TractAIAN','TractOMultir','TractHispanic','TractHUNV','TractSNAP']]
food_access = food_access.join(target_df)
food_access.head()
# Out:
#              OHU2010  PovertyRate  MedianFamilyIncome  TractKids  \
# CensusTract
# 1001020100       693    11.336453             81250.0      507.0
# 1001020200       743    17.876788             49000.0      606.0
# 1001020300      1256    15.046030             62609.0      894.0
# 1001020400      1722     2.845210             70607.0     1015.0
# 1001020500      4082    15.150891             96334.0     3162.0
#
#              TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  \
# CensusTract
# 1001020100          221.0      1622.0       217.0        14.0         0.0
# 1001020200          214.0       888.0      1217.0         5.0         0.0
# 1001020300          439.0      2576.0       647.0        17.0         5.0
# 1001020400          904.0      4086.0       193.0        18.0         4.0
# 1001020500         1126.0      8666.0      1437.0       296.0         9.0
#
#              TractAIAN  TractOMultir  TractHispanic  TractHUNV  TractSNAP  \
# CensusTract
# 1001020100        14.0          45.0           44.0        6.0      102.0
# 1001020200         5.0          55.0           75.0       89.0      156.0
# 1001020300        11.0         117.0           87.0       99.0      172.0
# 1001020400        11.0          74.0           85.0       21.0       98.0
# 1001020500        48.0         310.0          355.0      230.0      339.0
#
#              LILATracts_halfAnd10
# CensusTract
# 1001020100                      0
# 1001020200                      1
# 1001020300                      0
# 1001020400                      0
# 1001020500                      0

# %%
print(food_access.index)
# Out:
# Index([ 1001020100,  1001020200,  1001020300,  1001020400,  1001020500,
#         1001020600,  1001020700,  1001020801,  1001020802,  1001020900,
#        ...
#        56039967702, 56039967800, 56041975200, 56041975300, 56041975400,
#        56043000200, 56043000301, 56043000302, 56045951100, 56045951300],
#       dtype='int64', name='CensusTract', length=72531)

# %%
health_stats = pd.read_csv('../Data/500_Cities__View_a_city_s_census_tract_data__GIS_friendly_data_.csv')
health_stats.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               24.4      (21.2, 27.8)                 31.2
# 1            2735               30.4      (27.1, 33.7)                 30.5
# 2            3338               24.7      (21.1, 28.5)                 31.5
# 3            2864               25.2      (21.6, 29.0)                 35.0
# 4            2577               29.0      (24.5, 33.8)                 36.3
#
#   ARTHRITIS_Crude95CI  ...  PAPTEST_Crude95CI PHLTH_CrudePrev  \
# 0        (30.1, 32.2)  ...       (83.4, 86.6)            20.5
# 1        (29.3, 31.7)  ...       (81.9, 85.6)            22.2
# 2        (30.2, 32.9)  ...       (82.3, 86.8)            19.4
# 3        (33.5, 36.4)  ...       (82.1, 86.5)            21.7
# 4        (34.9, 37.7)  ...       (82.2, 87.1)            25.5
#
#    PHLTH_Crude95CI SLEEP_CrudePrev  SLEEP_Crude95CI STROKE_CrudePrev  \
# 0     (18.9, 22.2)            45.5     (44.3, 46.5)              5.5
# 1     (20.4, 24.0)            44.5     (43.2, 45.7)              6.1
# 2     (17.5, 21.4)            45.7     (44.2, 47.0)              5.6
# 3     (19.7, 23.9)            46.1     (44.5, 47.4)              7.3
# 4     (23.1, 28.0)            48.3     (46.6, 49.7)              9.0
#
#    STROKE_Crude95CI TEETHLOST_CrudePrev  TEETHLOST_Crude95CI  \
# 0      ( 5.0,  5.9)                28.9         (23.7, 35.1)
# 1      ( 5.5,  6.8)                32.9         (25.5, 40.2)
# 2      ( 5.0,  6.2)                28.6         (22.0, 35.1)
# 3      ( 6.5,  8.2)                34.0         (24.4, 42.9)
# 4      ( 8.1, 10.0)                43.2         (33.2, 53.2)
#
#                         Geolocation
# 0  (33.57943283260, -86.7228323926)
# 1  (33.54282086860, -86.7524339780)
# 2  (33.56324496330, -86.7640474064)
# 3  (33.54424045940, -86.7749130719)
# 4  (33.55254061390, -86.8016893706)
#
# [5 rows x 63 columns]

# %%
health_stats.set_index('TractFIPS', inplace=True)
health_stats.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# TractFIPS
# 1073000100            3042               24.4      (21.2, 27.8)
# 1073000300            2735               30.4      (27.1, 33.7)
# 1073000400            3338               24.7      (21.1, 28.5)
# 1073000500            2864               25.2      (21.6, 29.0)
# 1073000700            2577               29.0      (24.5, 33.8)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  ...  \
# TractFIPS                                                             ...
# 1073000100                 31.2        (30.1, 32.2)             10.3  ...
# 1073000300                 30.5        (29.3, 31.7)             10.5  ...
# 1073000400                 31.5        (30.2, 32.9)             10.4  ...
# 1073000500                 35.0        (33.5, 36.4)              9.1  ...
# 1073000700                 36.3        (34.9, 37.7)              7.6  ...
#
#            PAPTEST_Crude95CI  PHLTH_CrudePrev PHLTH_Crude95CI  \
# TractFIPS
# 1073000100      (83.4, 86.6)             20.5    (18.9, 22.2)
# 1073000300      (81.9, 85.6)             22.2    (20.4, 24.0)
# 1073000400      (82.3, 86.8)             19.4    (17.5, 21.4)
# 1073000500      (82.1, 86.5)             21.7    (19.7, 23.9)
# 1073000700      (82.2, 87.1)             25.5    (23.1, 28.0)
#
#             SLEEP_CrudePrev SLEEP_Crude95CI  STROKE_CrudePrev  \
# TractFIPS
# 1073000100             45.5    (44.3, 46.5)               5.5
# 1073000300             44.5    (43.2, 45.7)               6.1
# 1073000400             45.7    (44.2, 47.0)               5.6
# 1073000500             46.1    (44.5, 47.4)               7.3
# 1073000700             48.3    (46.6, 49.7)               9.0
#
#            STROKE_Crude95CI  TEETHLOST_CrudePrev TEETHLOST_Crude95CI  \
# TractFIPS
# 1073000100     ( 5.0,  5.9)                 28.9        (23.7, 35.1)
# 1073000300     ( 5.5,  6.8)                 32.9        (25.5, 40.2)
# 1073000400     ( 5.0,  6.2)                 28.6        (22.0, 35.1)
# 1073000500     ( 6.5,  8.2)                 34.0        (24.4, 42.9)
# 1073000700     ( 8.1, 10.0)                 43.2        (33.2, 53.2)
#
#                                  Geolocation
# TractFIPS
# 1073000100  (33.57943283260, -86.7228323926)
# 1073000300  (33.54282086860, -86.7524339780)
# 1073000400  (33.56324496330, -86.7640474064)
# 1073000500  (33.54424045940, -86.7749130719)
# 1073000700  (33.55254061390, -86.8016893706)
#
# [5 rows x 62 columns]

# %%
combined_data = health_stats.join(food_access)
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# TractFIPS
# 1073000100            3042               24.4      (21.2, 27.8)
# 1073000300            2735               30.4      (27.1, 33.7)
# 1073000400            3338               24.7      (21.1, 28.5)
# 1073000500            2864               25.2      (21.6, 29.0)
# 1073000700            2577               29.0      (24.5, 33.8)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  ...  \
# TractFIPS                                                             ...
# 1073000100                 31.2        (30.1, 32.2)             10.3  ...
# 1073000300                 30.5        (29.3, 31.7)             10.5  ...
# 1073000400                 31.5        (30.2, 32.9)             10.4  ...
# 1073000500                 35.0        (33.5, 36.4)              9.1  ...
# 1073000700                 36.3        (34.9, 37.7)              7.6  ...
#
#            TractWhite  TractBlack TractAsian  TractNHOPI TractAIAN  \
# TractFIPS
# 1073000100      530.0      2384.0       25.0         0.0       7.0
# 1073000300      498.0      1710.0       33.0         0.0       4.0
# 1073000400      256.0      2927.0       10.0         0.0       7.0
# 1073000500       83.0      2684.0        1.0        10.0       5.0
# 1073000700       12.0      2538.0        1.0         0.0       1.0
#
#             TractOMultir TractHispanic  TractHUNV TractSNAP  \
# TractFIPS
# 1073000100          96.0          82.0      227.0     361.0
# 1073000300         490.0         623.0      193.0     379.0
# 1073000400         138.0         162.0      205.0     442.0
# 1073000500          81.0          89.0      382.0     455.0
# 1073000700          25.0          12.0      246.0     575.0
#
#             LILATracts_halfAnd10
# TractFIPS
# 1073000100                   1.0
# 1073000300                   1.0
# 1073000400                   1.0
# 1073000500                   1.0
# 1073000700                   1.0
#
# [5 rows x 77 columns]

# %%
combined_data.shape
# Out:
# (27210, 77)

# %%
combined_data[combined_data['PlaceName'] == "New York"]
# Out:
#             StateAbbr PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 36005000100        NY  New York    3651000  3651000-36005000100
# 36005000200        NY  New York    3651000  3651000-36005000200
# 36005000400        NY  New York    3651000  3651000-36005000400
# 36005001600        NY  New York    3651000  3651000-36005001600
# 36005001900        NY  New York    3651000  3651000-36005001900
# ...               ...       ...        ...                  ...
# 36085030301        NY  New York    3651000  3651000-36085030301
# 36085030302        NY  New York    3651000  3651000-36085030302
# 36085031901        NY  New York    3651000  3651000-36085031901
# 36085031902        NY  New York    3651000  3651000-36085031902
# 36085032300        NY  New York    3651000  3651000-36085032300
#
#              Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# TractFIPS
# 36005000100           11091               31.8      (27.7, 35.6)
# 36005000200            4334               22.2      (18.8, 25.8)
# 36005000400            5503               17.6      (14.5, 21.0)
# 36005001600            5643               24.5      (20.7, 28.1)
# 36005001900            1917               22.3      (18.1, 26.5)
# ...                     ...                ...               ...
# 36085030301            4929               12.4      (10.8, 13.9)
# 36085030302            6369               14.5      (12.8, 16.4)
# 36085031901            3265               22.6      (19.5, 25.9)
# 36085031902            4848               18.6      (16.0, 21.3)
# 36085032300            1250               16.6      (14.5, 18.8)
#
#              ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  ...  \
# TractFIPS                                                              ...
# 36005000100                 12.5        (11.8, 13.2)             23.1  ...
# 36005000200                 19.5        (18.7, 20.4)             16.7  ...
# 36005000400                 17.3        (16.4, 18.2)             18.0  ...
# 36005001600                 24.2        (23.2, 25.2)             13.6  ...
# 36005001900                 15.6        (14.8, 16.4)             19.2  ...
# ...                          ...                 ...              ...  ...
# 36085030301                 22.0        (21.1, 22.8)             18.3  ...
# 36085030302                 20.2        (19.5, 20.8)             17.6  ...
# 36085031901                 23.6        (22.5, 24.6)             14.0  ...
# 36085031902                 21.7        (20.8, 22.6)             15.5  ...
# 36085032300                 23.4        (22.5, 24.2)             16.8  ...
#
#             TractWhite  TractBlack TractAsian  TractNHOPI TractAIAN  \
# TractFIPS
# 36005000100     1724.0      6515.0      180.0        28.0     117.0
# 36005000200     1332.0      1264.0      140.0        15.0      52.0
# 36005000400     1497.0      1735.0      124.0         6.0      48.0
# 36005001600     1556.0      2293.0       63.0         0.0      54.0
# 36005001900      591.0       641.0       25.0         1.0      22.0
# ...                ...         ...        ...         ...       ...
# 36085030301     2943.0       733.0      648.0         4.0      14.0
# 36085030302     2926.0      1404.0      864.0         8.0      50.0
# 36085031901      593.0      1948.0      119.0         1.0      21.0
# 36085031902      997.0      2918.0      101.0         1.0      43.0
# 36085032300      485.0       508.0       42.0         1.0       7.0
#
#              TractOMultir TractHispanic  TractHUNV TractSNAP  \
# TractFIPS
# 36005000100        2527.0        3779.0        0.0       0.0
# 36005000200        1531.0        2993.0      269.0     275.0
# 36005000400        2093.0        3755.0      432.0     265.0
# 36005001600        1677.0        3482.0      998.0     649.0
# 36005001900         637.0        1186.0      598.0     261.0
# ...                   ...           ...        ...       ...
# 36085030301         587.0        1215.0      167.0      87.0
# 36085030302        1117.0        2163.0      152.0     260.0
# 36085031901         583.0        1092.0      701.0     707.0
# 36085031902         788.0        1498.0      663.0     538.0
# 36085032300         207.0         442.0       71.0      58.0
#
#              LILATracts_halfAnd10
# TractFIPS
# 36005000100                   0.0
# 36005000200                   0.0
# 36005000400                   0.0
# 36005001600                   0.0
# 36005001900                   0.0
# ...                           ...
# 36085030301                   0.0
# 36085030302                   0.0
# 36085031901                   1.0
# 36085031902                   1.0
# 36085032300                   1.0
#
# [2117 rows x 77 columns]

# %%
combined_data.shape
# Out:
# (27210, 77)

# %%
combined_data.rename(columns={'LILATracts_halfAnd10': 'target'}, inplace=True)
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  \
# TractFIPS
# 1073000100            3042               24.4      (21.2, 27.8)
# 1073000300            2735               30.4      (27.1, 33.7)
# 1073000400            3338               24.7      (21.1, 28.5)
# 1073000500            2864               25.2      (21.6, 29.0)
# 1073000700            2577               29.0      (24.5, 33.8)
#
#             ARTHRITIS_CrudePrev ARTHRITIS_Crude95CI  BINGE_CrudePrev  ...  \
# TractFIPS                                                             ...
# 1073000100                 31.2        (30.1, 32.2)             10.3  ...
# 1073000300                 30.5        (29.3, 31.7)             10.5  ...
# 1073000400                 31.5        (30.2, 32.9)             10.4  ...
# 1073000500                 35.0        (33.5, 36.4)              9.1  ...
# 1073000700                 36.3        (34.9, 37.7)              7.6  ...
#
#            TractWhite  TractBlack TractAsian  TractNHOPI TractAIAN  \
# TractFIPS
# 1073000100      530.0      2384.0       25.0         0.0       7.0
# 1073000300      498.0      1710.0       33.0         0.0       4.0
# 1073000400      256.0      2927.0       10.0         0.0       7.0
# 1073000500       83.0      2684.0        1.0        10.0       5.0
# 1073000700       12.0      2538.0        1.0         0.0       1.0
#
#             TractOMultir TractHispanic  TractHUNV TractSNAP  target
# TractFIPS
# 1073000100          96.0          82.0      227.0     361.0     1.0
# 1073000300         490.0         623.0      193.0     379.0     1.0
# 1073000400         138.0         162.0      205.0     442.0     1.0
# 1073000500          81.0          89.0      382.0     455.0     1.0
# 1073000700          25.0          12.0      246.0     575.0     1.0
#
# [5 rows x 77 columns]

# %% [markdown]
# ##### Drop columns that represent confidence intervals or other similar statistical measures rather than actual data points.

# %%
to_drop = [x for x in combined_data.columns if x[-2:] == "CI"]

# %%
combined_data.drop(columns=to_drop, inplace=True)
combined_data.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev  ARTHRITIS_CrudePrev  \
# TractFIPS
# 1073000100            3042               24.4                 31.2
# 1073000300            2735               30.4                 30.5
# 1073000400            3338               24.7                 31.5
# 1073000500            2864               25.2                 35.0
# 1073000700            2577               29.0                 36.3
#
#             BINGE_CrudePrev  BPHIGH_CrudePrev  BPMED_CrudePrev  ...  \
# TractFIPS                                                       ...
# 1073000100             10.3              47.7             77.8  ...
# 1073000300             10.5              48.2             78.5  ...
# 1073000400             10.4              49.1             79.4  ...
# 1073000500              9.1              54.1             82.1  ...
# 1073000700              7.6              56.5             81.8  ...
#
#             TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# TractFIPS
# 1073000100       530.0      2384.0        25.0         0.0        7.0
# 1073000300       498.0      1710.0        33.0         0.0        4.0
# 1073000400       256.0      2927.0        10.0         0.0        7.0
# 1073000500        83.0      2684.0         1.0        10.0        5.0
# 1073000700        12.0      2538.0         1.0         0.0        1.0
#
#             TractOMultir  TractHispanic  TractHUNV  TractSNAP  target
# TractFIPS
# 1073000100          96.0           82.0      227.0      361.0     1.0
# 1073000300         490.0          623.0      193.0      379.0     1.0
# 1073000400         138.0          162.0      205.0      442.0     1.0
# 1073000500          81.0           89.0      382.0      455.0     1.0
# 1073000700          25.0           12.0      246.0      575.0     1.0
#
# [5 rows x 49 columns]

# %%
combined_data.shape
# Out:
# (27210, 49)

# %%
col_names = combined_data.columns.tolist()
print(col_names)
# Out:
# ['StateAbbr', 'PlaceName', 'PlaceFIPS', 'Place_TractID', 'Population2010', 'ACCESS2_CrudePrev', 'ARTHRITIS_CrudePrev', 'BINGE_CrudePrev', 'BPHIGH_CrudePrev', 'BPMED_CrudePrev', 'CANCER_CrudePrev', 'CASTHMA_CrudePrev', 'CHD_CrudePrev', 'CHECKUP_CrudePrev', 'CHOLSCREEN_CrudePrev', 'COLON_SCREEN_CrudePrev', 'COPD_CrudePrev', 'COREM_CrudePrev', 'COREW_CrudePrev', 'CSMOKING_CrudePrev', 'DENTAL_CrudePrev', 'DIABETES_CrudePrev', 'HIGHCHOL_CrudePrev', 'KIDNEY_CrudePrev', 'LPA_CrudePrev', 'MAMMOUSE_CrudePrev', 'MHLTH_CrudePrev', 'OBESITY_CrudePrev', 'PAPTEST_CrudePrev', 'PHLTH_CrudePrev', 'SLEEP_CrudePrev', 'STROKE_CrudePrev', 'TEETHLOST_CrudePrev', 'Geolocation', 'OHU2010', 'PovertyRate', 'MedianFamilyIncome', 'TractKids', 'TractSeniors', 'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP', 'target']

# %% [markdown]
# #### Fixing demographic columns to percentages

# %%
# List of demographic columns
demographic_columns = ['TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN', 'TractOMultir', 'TractHispanic']

# Function to fix demographic columns to percentages
def fix_demographic_columns(combined_data, demographic_columns):
    for col in demographic_columns:
        new_col_name = "Percent_" + col
        combined_data[new_col_name] = combined_data[col] / combined_data['Population2010'] * 100
    return combined_data

# Apply the function
df = fix_demographic_columns(combined_data, demographic_columns)

# Drop the original count columns if needed
# df.drop(demographic_columns, axis=1, inplace=True)

# Display the updated DataFrame
df.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev  ARTHRITIS_CrudePrev  \
# TractFIPS
# 1073000100            3042               24.4                 31.2
# 1073000300            2735               30.4                 30.5
# 1073000400            3338               24.7                 31.5
# 1073000500            2864               25.2                 35.0
# 1073000700            2577               29.0                 36.3
#
#             BINGE_CrudePrev  BPHIGH_CrudePrev  BPMED_CrudePrev  ...  \
# TractFIPS                                                       ...
# 1073000100             10.3              47.7             77.8  ...
# 1073000300             10.5              48.2             78.5  ...
# 1073000400             10.4              49.1             79.4  ...
# 1073000500              9.1              54.1             82.1  ...
# 1073000700              7.6              56.5             81.8  ...
#
#             TractHUNV  TractSNAP  target  Percent_TractWhite  \
# TractFIPS
# 1073000100      227.0      361.0     1.0           17.422748
# 1073000300      193.0      379.0     1.0           18.208410
# 1073000400      205.0      442.0     1.0            7.669263
# 1073000500      382.0      455.0     1.0            2.898045
# 1073000700      246.0      575.0     1.0            0.465658
#
#             Percent_TractBlack  Percent_TractAsian  Percent_TractNHOPI  \
# TractFIPS
# 1073000100           78.369494            0.821828            0.000000
# 1073000300           62.522852            1.206581            0.000000
# 1073000400           87.687238            0.299581            0.000000
# 1073000500           93.715084            0.034916            0.349162
# 1073000700           98.486612            0.038805            0.000000
#
#             Percent_TractAIAN  Percent_TractOMultir  Percent_TractHispanic
# TractFIPS
# 1073000100           0.230112              3.155819               2.695595
# 1073000300           0.146252             17.915905              22.778793
# 1073000400           0.209706              4.134212               4.853206
# 1073000500           0.174581              2.828212               3.107542
# 1073000700           0.038805              0.970120               0.465658
#
# [5 rows x 56 columns]

# %%
df.to_csv('../csv_data/final_df.csv')

# %%
df.columns
# Out:
# Index(['StateAbbr', 'PlaceName', 'PlaceFIPS', 'Place_TractID',
#        'Population2010', 'ACCESS2_CrudePrev', 'ARTHRITIS_CrudePrev',
#        'BINGE_CrudePrev', 'BPHIGH_CrudePrev', 'BPMED_CrudePrev',
#        'CANCER_CrudePrev', 'CASTHMA_CrudePrev', 'CHD_CrudePrev',
#        'CHECKUP_CrudePrev', 'CHOLSCREEN_CrudePrev', 'COLON_SCREEN_CrudePrev',
#        'COPD_CrudePrev', 'COREM_CrudePrev', 'COREW_CrudePrev',
#        'CSMOKING_CrudePrev', 'DENTAL_CrudePrev', 'DIABETES_CrudePrev',
#        'HIGHCHOL_CrudePrev', 'KIDNEY_CrudePrev', 'LPA_CrudePrev',
#        'MAMMOUSE_CrudePrev', 'MHLTH_CrudePrev', 'OBESITY_CrudePrev',
#        'PAPTEST_CrudePrev', 'PHLTH_CrudePrev', 'SLEEP_CrudePrev',
#        'STROKE_CrudePrev', 'TEETHLOST_CrudePrev', 'Geolocation', 'OHU2010',
#        'PovertyRate', 'MedianFamilyIncome', 'TractKids', 'TractSeniors',
#        'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN',
#        'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP', 'target',
#        'Percent_TractWhite', 'Percent_TractBlack', 'Percent_TractAsian',
#        'Percent_TractNHOPI', 'Percent_TractAIAN', 'Percent_TractOMultir',
#        'Percent_TractHispanic'],
#       dtype='object')

# %%
# Calculate correlation matrix
correlation_matrix = df.corr(numeric_only = True)

# Create heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Convert correlation matrix to DataFrame for better visualization
correlation_df = pd.DataFrame(correlation_matrix, columns=df.columns, index=df.columns)

# Display correlation table
correlation_df
# Out:
#                         StateAbbr  PlaceName  PlaceFIPS  Place_TractID  \
# StateAbbr                     NaN        NaN        NaN            NaN
# PlaceName                     NaN        NaN        NaN            NaN
# PlaceFIPS                     NaN        NaN   1.000000            NaN
# Place_TractID                 NaN        NaN        NaN            NaN
# Population2010                NaN        NaN  -0.046678            NaN
# ACCESS2_CrudePrev             NaN        NaN   0.166580            NaN
# ARTHRITIS_CrudePrev           NaN        NaN   0.112204            NaN
# BINGE_CrudePrev               NaN        NaN   0.010589            NaN
# BPHIGH_CrudePrev              NaN        NaN   0.118149            NaN
# BPMED_CrudePrev               NaN        NaN   0.128139            NaN
# CANCER_CrudePrev              NaN        NaN  -0.018671            NaN
# CASTHMA_CrudePrev             NaN        NaN   0.097460            NaN
# CHD_CrudePrev                 NaN        NaN   0.084351            NaN
# CHECKUP_CrudePrev             NaN        NaN   0.115160            NaN
# CHOLSCREEN_CrudePrev          NaN        NaN  -0.109357            NaN
# COLON_SCREEN_CrudePrev        NaN        NaN  -0.087450            NaN
# COPD_CrudePrev                NaN        NaN   0.073288            NaN
# COREM_CrudePrev               NaN        NaN   0.046235            NaN
# COREW_CrudePrev               NaN        NaN  -0.029642            NaN
# CSMOKING_CrudePrev            NaN        NaN   0.176520            NaN
# DENTAL_CrudePrev              NaN        NaN  -0.075160            NaN
# DIABETES_CrudePrev            NaN        NaN   0.101665            NaN
# HIGHCHOL_CrudePrev            NaN        NaN   0.062948            NaN
# KIDNEY_CrudePrev              NaN        NaN   0.008341            NaN
# LPA_CrudePrev                 NaN        NaN   0.232882            NaN
# MAMMOUSE_CrudePrev            NaN        NaN  -0.095876            NaN
# MHLTH_CrudePrev               NaN        NaN   0.130097            NaN
# OBESITY_CrudePrev             NaN        NaN   0.241164            NaN
# PAPTEST_CrudePrev             NaN        NaN  -0.123316            NaN
# PHLTH_CrudePrev               NaN        NaN   0.075047            NaN
# SLEEP_CrudePrev               NaN        NaN   0.052372            NaN
# STROKE_CrudePrev              NaN        NaN   0.065246            NaN
# TEETHLOST_CrudePrev           NaN        NaN   0.135887            NaN
# Geolocation                   NaN        NaN        NaN            NaN
# OHU2010                       NaN        NaN   0.013569            NaN
# PovertyRate                   NaN        NaN   0.086876            NaN
# MedianFamilyIncome            NaN        NaN  -0.097941            NaN
# TractKids                     NaN        NaN  -0.022485            NaN
# TractSeniors                  NaN        NaN  -0.075790            NaN
# TractWhite                    NaN        NaN   0.019469            NaN
# TractBlack                    NaN        NaN   0.112626            NaN
# TractAsian                    NaN        NaN  -0.184031            NaN
# TractNHOPI                    NaN        NaN  -0.121864            NaN
# TractAIAN                     NaN        NaN  -0.025937            NaN
# TractOMultir                  NaN        NaN  -0.182064            NaN
# TractHispanic                 NaN        NaN  -0.090550            NaN
# TractHUNV                     NaN        NaN   0.108336            NaN
# TractSNAP                     NaN        NaN   0.140488            NaN
# target                        NaN        NaN   0.060932            NaN
# Percent_TractWhite            NaN        NaN   0.022578            NaN
# Percent_TractBlack            NaN        NaN   0.038883            NaN
# Percent_TractAsian            NaN        NaN  -0.034428            NaN
# Percent_TractNHOPI            NaN        NaN  -0.030975            NaN
# Percent_TractAIAN             NaN        NaN   0.016406            NaN
# Percent_TractOMultir          NaN        NaN  -0.024532            NaN
# Percent_TractHispanic         NaN        NaN  -0.002210            NaN
#
#                         Population2010  ACCESS2_CrudePrev  \
# StateAbbr                          NaN                NaN
# PlaceName                          NaN                NaN
# PlaceFIPS                    -0.046678           0.166580
# Place_TractID                      NaN                NaN
# Population2010                1.000000           0.049058
# ACCESS2_CrudePrev             0.049058           1.000000
# ARTHRITIS_CrudePrev          -0.208813           0.015160
# BINGE_CrudePrev               0.074835          -0.377052
# BPHIGH_CrudePrev             -0.195947           0.320869
# BPMED_CrudePrev              -0.150218          -0.033556
# CANCER_CrudePrev             -0.122140          -0.382636
# CASTHMA_CrudePrev            -0.151463           0.225258
# CHD_CrudePrev                -0.185568           0.335850
# CHECKUP_CrudePrev            -0.162611          -0.089369
# CHOLSCREEN_CrudePrev         -0.045816          -0.445822
# COLON_SCREEN_CrudePrev        0.005516          -0.831361
# COPD_CrudePrev               -0.190817           0.380779
# COREM_CrudePrev               0.019579          -0.672686
# COREW_CrudePrev               0.025905          -0.697447
# CSMOKING_CrudePrev           -0.137624           0.541858
# DENTAL_CrudePrev              0.049468          -0.817286
# DIABETES_CrudePrev           -0.137158           0.568320
# HIGHCHOL_CrudePrev           -0.129161           0.175552
# KIDNEY_CrudePrev             -0.154752           0.489789
# LPA_CrudePrev                -0.103063           0.759961
# MAMMOUSE_CrudePrev           -0.068062          -0.180386
# MHLTH_CrudePrev              -0.070191           0.649176
# OBESITY_CrudePrev            -0.143907           0.604421
# PAPTEST_CrudePrev            -0.080757          -0.295224
# PHLTH_CrudePrev              -0.115338           0.651860
# SLEEP_CrudePrev              -0.082999           0.441585
# STROKE_CrudePrev             -0.192238           0.396214
# TEETHLOST_CrudePrev          -0.119823           0.653484
# Geolocation                        NaN                NaN
# OHU2010                       0.689297          -0.171289
# PovertyRate                  -0.089976           0.552071
# MedianFamilyIncome            0.037033          -0.638776
# TractKids                     0.638272           0.238375
# TractSeniors                  0.406105          -0.199368
# TractWhite                    0.533602          -0.200713
# TractBlack                    0.156333           0.219377
# TractAsian                    0.324678          -0.197211
# TractNHOPI                    0.122370          -0.040346
# TractAIAN                     0.230790           0.146771
# TractOMultir                  0.447982           0.445417
# TractHispanic                 0.427039           0.588175
# TractHUNV                     0.233439           0.032416
# TractSNAP                     0.296169           0.484006
# target                       -0.004731           0.408808
# Percent_TractWhite           -0.237505          -0.044186
# Percent_TractBlack           -0.154664           0.065451
# Percent_TractAsian           -0.106726          -0.056537
# Percent_TractNHOPI           -0.072705          -0.015293
# Percent_TractAIAN            -0.103548           0.012333
# Percent_TractOMultir         -0.150595           0.092875
# Percent_TractHispanic        -0.136281           0.128763
#
#                         ARTHRITIS_CrudePrev  BINGE_CrudePrev  \
# StateAbbr                               NaN              NaN
# PlaceName                               NaN              NaN
# PlaceFIPS                          0.112204         0.010589
# Place_TractID                           NaN              NaN
# Population2010                    -0.208813         0.074835
# ACCESS2_CrudePrev                  0.015160        -0.377052
# ARTHRITIS_CrudePrev                1.000000        -0.618568
# BINGE_CrudePrev                   -0.618568         1.000000
# BPHIGH_CrudePrev                   0.859888        -0.734661
# BPMED_CrudePrev                    0.828140        -0.562631
# CANCER_CrudePrev                   0.715015        -0.316014
# CASTHMA_CrudePrev                  0.480158        -0.428476
# CHD_CrudePrev                      0.877556        -0.702196
# CHECKUP_CrudePrev                  0.624709        -0.441079
# CHOLSCREEN_CrudePrev               0.353688        -0.110552
# COLON_SCREEN_CrudePrev            -0.025253         0.342064
# COPD_CrudePrev                     0.806639        -0.636480
# COREM_CrudePrev                   -0.056999         0.410749
# COREW_CrudePrev                   -0.160655         0.405161
# CSMOKING_CrudePrev                 0.437621        -0.379076
# DENTAL_CrudePrev                  -0.217404         0.480441
# DIABETES_CrudePrev                 0.676042        -0.743833
# HIGHCHOL_CrudePrev                 0.825677        -0.654596
# KIDNEY_CrudePrev                   0.746733        -0.760000
# LPA_CrudePrev                      0.465061        -0.602233
# MAMMOUSE_CrudePrev                 0.009526        -0.021735
# MHLTH_CrudePrev                    0.248480        -0.384136
# OBESITY_CrudePrev                  0.523238        -0.486719
# PAPTEST_CrudePrev                  0.111615         0.164205
# PHLTH_CrudePrev                    0.618387        -0.670255
# SLEEP_CrudePrev                    0.278209        -0.444399
# STROKE_CrudePrev                   0.784451        -0.716227
# TEETHLOST_CrudePrev                0.409113        -0.520235
# Geolocation                             NaN              NaN
# OHU2010                           -0.117940         0.160931
# PovertyRate                        0.188154        -0.387947
# MedianFamilyIncome                -0.280425         0.447806
# TractKids                         -0.139822        -0.052905
# TractSeniors                       0.321362        -0.186672
# TractWhite                        -0.172541         0.317356
# TractBlack                         0.248608        -0.331693
# TractAsian                        -0.322244         0.001764
# TractNHOPI                        -0.069892         0.014090
# TractAIAN                         -0.096013        -0.025358
# TractOMultir                      -0.317507        -0.019418
# TractHispanic                     -0.297844        -0.038996
# TractHUNV                         -0.043437         0.022746
# TractSNAP                          0.213824        -0.337876
# target                             0.194408        -0.274890
# Percent_TractWhite                 0.036638         0.021225
# Percent_TractBlack                 0.087115        -0.100800
# Percent_TractAsian                -0.072655        -0.001836
# Percent_TractNHOPI                -0.021015        -0.001926
# Percent_TractAIAN                  0.020458        -0.021272
# Percent_TractOMultir              -0.039796        -0.012439
# Percent_TractHispanic             -0.040413        -0.015088
#
#                         BPHIGH_CrudePrev  BPMED_CrudePrev  ...  TractHUNV  \
# StateAbbr                            NaN              NaN  ...        NaN
# PlaceName                            NaN              NaN  ...        NaN
# PlaceFIPS                       0.118149         0.128139  ...   0.108336
# Place_TractID                        NaN              NaN  ...        NaN
# Population2010                 -0.195947        -0.150218  ...   0.233439
# ACCESS2_CrudePrev               0.320869        -0.033556  ...   0.032416
# ARTHRITIS_CrudePrev             0.859888         0.828140  ...  -0.043437
# BINGE_CrudePrev                -0.734661        -0.562631  ...   0.022746
# BPHIGH_CrudePrev                1.000000         0.764487  ...   0.017962
# BPMED_CrudePrev                 0.764487         1.000000  ...   0.048855
# CANCER_CrudePrev                0.414397         0.708720  ...  -0.096008
# CASTHMA_CrudePrev               0.591753         0.223763  ...   0.134640
# CHD_CrudePrev                   0.881922         0.730789  ...   0.062613
# CHECKUP_CrudePrev               0.678252         0.719166  ...   0.176566
# CHOLSCREEN_CrudePrev            0.222378         0.599385  ...   0.008961
# COLON_SCREEN_CrudePrev         -0.294513         0.105354  ...  -0.109548
# COPD_CrudePrev                  0.852756         0.575838  ...   0.049124
# COREM_CrudePrev                -0.373963         0.008992  ...  -0.222783
# COREW_CrudePrev                -0.428000        -0.032525  ...  -0.239125
# CSMOKING_CrudePrev              0.606235         0.205995  ...   0.070428
# DENTAL_CrudePrev               -0.514518        -0.050304  ...  -0.110379
# DIABETES_CrudePrev              0.899804         0.604927  ...   0.108866
# HIGHCHOL_CrudePrev              0.767132         0.843989  ...  -0.060578
# KIDNEY_CrudePrev                0.885130         0.620517  ...   0.116729
# LPA_CrudePrev                   0.720440         0.353917  ...   0.136086
# MAMMOUSE_CrudePrev              0.141280         0.126026  ...   0.109652
# MHLTH_CrudePrev                 0.454347        -0.031607  ...   0.104525
# OBESITY_CrudePrev               0.745852         0.345474  ...  -0.029881
# PAPTEST_CrudePrev               0.099114         0.199199  ...   0.020617
# PHLTH_CrudePrev                 0.780187         0.416275  ...   0.093707
# SLEEP_CrudePrev                 0.556577         0.195300  ...   0.181545
# STROKE_CrudePrev                0.929248         0.644764  ...   0.115153
# TEETHLOST_CrudePrev             0.638172         0.208305  ...   0.154224
# Geolocation                          NaN              NaN  ...        NaN
# OHU2010                        -0.205171        -0.041137  ...   0.305173
# PovertyRate                     0.412777         0.007232  ...   0.230276
# MedianFamilyIncome             -0.466511        -0.098615  ...  -0.048994
# TractKids                      -0.080792        -0.119465  ...  -0.012261
# TractSeniors                    0.153596         0.377400  ...   0.165272
# TractWhite                     -0.397641        -0.187312  ...  -0.047249
# TractBlack                      0.509252         0.250876  ...   0.252969
# TractAsian                     -0.273693        -0.155993  ...   0.102843
# TractNHOPI                     -0.045522        -0.066432  ...  -0.031390
# TractAIAN                      -0.101207        -0.155087  ...   0.030412
# TractOMultir                   -0.190787        -0.317664  ...   0.122712
# TractHispanic                  -0.154378        -0.265337  ...   0.083530
# TractHUNV                       0.017962         0.048855  ...   1.000000
# TractSNAP                       0.360896         0.142205  ...   0.440124
# target                          0.323243         0.039479  ...  -0.040166
# Percent_TractWhite             -0.020997        -0.000040  ...  -0.067924
# Percent_TractBlack              0.160876         0.071947  ...   0.011152
# Percent_TractAsian             -0.067080        -0.045669  ...  -0.020164
# Percent_TractNHOPI             -0.020043        -0.050669  ...  -0.031695
# Percent_TractAIAN               0.004683        -0.010852  ...  -0.025578
# Percent_TractOMultir           -0.022365        -0.068786  ...  -0.030181
# Percent_TractHispanic          -0.014820        -0.054783  ...  -0.029543
#
#                         TractSNAP    target  Percent_TractWhite  \
# StateAbbr                     NaN       NaN                 NaN
# PlaceName                     NaN       NaN                 NaN
# PlaceFIPS                0.140488  0.060932            0.022578
# Place_TractID                 NaN       NaN                 NaN
# Population2010           0.296169 -0.004731           -0.237505
# ACCESS2_CrudePrev        0.484006  0.408808           -0.044186
# ARTHRITIS_CrudePrev      0.213824  0.194408            0.036638
# BINGE_CrudePrev         -0.337876 -0.274890            0.021225
# BPHIGH_CrudePrev         0.360896  0.323243           -0.020997
# BPMED_CrudePrev          0.142205  0.039479           -0.000040
# CANCER_CrudePrev        -0.184598 -0.164784            0.098193
# CASTHMA_CrudePrev        0.470210  0.405510           -0.090961
# CHD_CrudePrev            0.363165  0.303833           -0.004263
# CHECKUP_CrudePrev        0.151761  0.002816           -0.031324
# CHOLSCREEN_CrudePrev    -0.275205 -0.391748            0.049833
# COLON_SCREEN_CrudePrev  -0.525933 -0.432977            0.074151
# COPD_CrudePrev           0.447519  0.410838           -0.025080
# COREM_CrudePrev         -0.494290 -0.365881            0.104114
# COREW_CrudePrev         -0.574066 -0.427042            0.109986
# CSMOKING_CrudePrev       0.540407  0.500073           -0.068671
# DENTAL_CrudePrev        -0.581204 -0.519525            0.087031
# DIABETES_CrudePrev       0.486220  0.380956           -0.060979
# HIGHCHOL_CrudePrev       0.159226  0.101637            0.038091
# KIDNEY_CrudePrev         0.476232  0.378132           -0.052400
# LPA_CrudePrev            0.580942  0.460842           -0.065342
# MAMMOUSE_CrudePrev       0.019222 -0.052209           -0.070216
# MHLTH_CrudePrev          0.580598  0.528434           -0.079223
# OBESITY_CrudePrev        0.506426  0.499376           -0.046300
# PAPTEST_CrudePrev       -0.090258 -0.146399           -0.016723
# PHLTH_CrudePrev          0.578418  0.469797           -0.054348
# SLEEP_CrudePrev          0.469631  0.337348           -0.118139
# STROKE_CrudePrev         0.446363  0.378263           -0.054811
# TEETHLOST_CrudePrev      0.582285  0.515175           -0.088581
# Geolocation                   NaN       NaN                 NaN
# OHU2010                  0.237160 -0.105642            0.112554
# PovertyRate              0.547595  0.476396           -0.101023
# MedianFamilyIncome      -0.561146 -0.500059            0.071454
# TractKids                0.373373  0.046596            0.121436
# TractSeniors             0.103202 -0.136380            0.108824
# TractWhite              -0.064752 -0.197998            0.199368
# TractBlack               0.503730  0.256740           -0.073949
# TractAsian              -0.087672 -0.170203           -0.005405
# TractNHOPI               0.024376 -0.003637           -0.009146
# TractAIAN                0.207061  0.087491            0.032674
# TractOMultir             0.348214  0.103095           -0.010794
# TractHispanic            0.364676  0.114123            0.019330
# TractHUNV                0.440124 -0.040166           -0.067924
# TractSNAP                1.000000  0.358228           -0.042743
# target                   0.358228  1.000000           -0.060984
# Percent_TractWhite      -0.042743 -0.060984            1.000000
# Percent_TractBlack       0.099567  0.057923            0.314246
# Percent_TractAsian      -0.041854 -0.050684            0.459434
# Percent_TractNHOPI       0.004392  0.005512            0.273290
# Percent_TractAIAN        0.009145 -0.003531            0.391949
# Percent_TractOMultir     0.041002  0.020649            0.559875
# Percent_TractHispanic    0.053727  0.028562            0.586850
#
#                         Percent_TractBlack  Percent_TractAsian  \
# StateAbbr                              NaN                 NaN
# PlaceName                              NaN                 NaN
# PlaceFIPS                         0.038883           -0.034428
# Place_TractID                          NaN                 NaN
# Population2010                   -0.154664           -0.106726
# ACCESS2_CrudePrev                 0.065451           -0.056537
# ARTHRITIS_CrudePrev               0.087115           -0.072655
# BINGE_CrudePrev                  -0.100800           -0.001836
# BPHIGH_CrudePrev                  0.160876           -0.067080
# BPMED_CrudePrev                   0.071947           -0.045669
# CANCER_CrudePrev                 -0.023088           -0.010365
# CASTHMA_CrudePrev                 0.139041           -0.112810
# CHD_CrudePrev                     0.076636           -0.063980
# CHECKUP_CrudePrev                 0.140553           -0.029802
# CHOLSCREEN_CrudePrev              0.018244            0.041606
# COLON_SCREEN_CrudePrev           -0.054570            0.045463
# COPD_CrudePrev                    0.109406           -0.092449
# COREM_CrudePrev                  -0.114445            0.033104
# COREW_CrudePrev                  -0.092212            0.060230
# CSMOKING_CrudePrev                0.120503           -0.102800
# DENTAL_CrudePrev                 -0.102631            0.062566
# DIABETES_CrudePrev                0.131267           -0.050778
# HIGHCHOL_CrudePrev                0.036314           -0.022037
# KIDNEY_CrudePrev                  0.107549           -0.064902
# LPA_CrudePrev                     0.126463           -0.083365
# MAMMOUSE_CrudePrev                0.109272           -0.023264
# MHLTH_CrudePrev                   0.099068           -0.096622
# OBESITY_CrudePrev                 0.155084           -0.118533
# PAPTEST_CrudePrev                 0.054852           -0.081053
# PHLTH_CrudePrev                   0.101012           -0.082394
# SLEEP_CrudePrev                   0.150867           -0.041931
# STROKE_CrudePrev                  0.142240           -0.067532
# TEETHLOST_CrudePrev               0.148057           -0.086102
# Geolocation                            NaN                 NaN
# OHU2010                           0.020956            0.070439
# PovertyRate                       0.074614           -0.070199
# MedianFamilyIncome               -0.083314            0.080245
# TractKids                         0.070809            0.097501
# TractSeniors                     -0.012179            0.048342
# TractWhite                       -0.082257            0.051140
# TractBlack                        0.258518           -0.040787
# TractAsian                       -0.043748            0.245087
# TractNHOPI                       -0.018128            0.037101
# TractAIAN                        -0.024589            0.003193
# TractOMultir                     -0.022992            0.040452
# TractHispanic                    -0.027518            0.024123
# TractHUNV                         0.011152           -0.020164
# TractSNAP                         0.099567           -0.041854
# target                            0.057923           -0.050684
# Percent_TractWhite                0.314246            0.459434
# Percent_TractBlack                1.000000            0.193270
# Percent_TractAsian                0.193270            1.000000
# Percent_TractNHOPI                0.137420            0.307701
# Percent_TractAIAN                 0.173715            0.179957
# Percent_TractOMultir              0.414823            0.438517
# Percent_TractHispanic             0.339941            0.369069
#
#                         Percent_TractNHOPI  Percent_TractAIAN  \
# StateAbbr                              NaN                NaN
# PlaceName                              NaN                NaN
# PlaceFIPS                        -0.030975           0.016406
# Place_TractID                          NaN                NaN
# Population2010                   -0.072705          -0.103548
# ACCESS2_CrudePrev                -0.015293           0.012333
# ARTHRITIS_CrudePrev              -0.021015           0.020458
# BINGE_CrudePrev                  -0.001926          -0.021272
# BPHIGH_CrudePrev                 -0.020043           0.004683
# BPMED_CrudePrev                  -0.050669          -0.010852
# CANCER_CrudePrev                 -0.004683           0.018019
# CASTHMA_CrudePrev                -0.016899          -0.000882
# CHD_CrudePrev                    -0.017731           0.014640
# CHECKUP_CrudePrev                -0.053516          -0.049696
# CHOLSCREEN_CrudePrev             -0.038359          -0.025565
# COLON_SCREEN_CrudePrev            0.005488          -0.020864
# COPD_CrudePrev                   -0.032314           0.010946
# COREM_CrudePrev                  -0.004528           0.019055
# COREW_CrudePrev                  -0.003319           0.004524
# CSMOKING_CrudePrev               -0.026781           0.007905
# DENTAL_CrudePrev                  0.007573          -0.009220
# DIABETES_CrudePrev               -0.012528          -0.002839
# HIGHCHOL_CrudePrev               -0.011178           0.022922
# KIDNEY_CrudePrev                 -0.002490           0.004817
# LPA_CrudePrev                    -0.031700           0.004465
# MAMMOUSE_CrudePrev               -0.034647          -0.064254
# MHLTH_CrudePrev                  -0.012056           0.011249
# OBESITY_CrudePrev                -0.031406           0.010052
# PAPTEST_CrudePrev                -0.069391          -0.026690
# PHLTH_CrudePrev                  -0.005384           0.017095
# SLEEP_CrudePrev                   0.027133          -0.028541
# STROKE_CrudePrev                 -0.018146          -0.003052
# TEETHLOST_CrudePrev              -0.028565          -0.000571
# Geolocation                            NaN                NaN
# OHU2010                           0.015719           0.023914
# PovertyRate                      -0.031139          -0.014803
# MedianFamilyIncome                0.000373          -0.011971
# TractKids                         0.065182           0.058850
# TractSeniors                      0.014564           0.009769
# TractWhite                        0.011837           0.048049
# TractBlack                       -0.033884          -0.024941
# TractAsian                        0.081990          -0.008870
# TractNHOPI                        0.339141           0.005012
# TractAIAN                         0.037578           0.319493
# TractOMultir                      0.078227           0.046886
# TractHispanic                     0.027800           0.041205
# TractHUNV                        -0.031695          -0.025578
# TractSNAP                         0.004392           0.009145
# target                            0.005512          -0.003531
# Percent_TractWhite                0.273290           0.391949
# Percent_TractBlack                0.137420           0.173715
# Percent_TractAsian                0.307701           0.179957
# Percent_TractNHOPI                1.000000           0.206898
# Percent_TractAIAN                 0.206898           1.000000
# Percent_TractOMultir              0.400572           0.393191
# Percent_TractHispanic             0.288935           0.327163
#
#                         Percent_TractOMultir  Percent_TractHispanic
# StateAbbr                                NaN                    NaN
# PlaceName                                NaN                    NaN
# PlaceFIPS                          -0.024532              -0.002210
# Place_TractID                            NaN                    NaN
# Population2010                     -0.150595              -0.136281
# ACCESS2_CrudePrev                   0.092875               0.128763
# ARTHRITIS_CrudePrev                -0.039796              -0.040413
# BINGE_CrudePrev                    -0.012439              -0.015088
# BPHIGH_CrudePrev                   -0.022365              -0.014820
# BPMED_CrudePrev                    -0.068786              -0.054783
# CANCER_CrudePrev                   -0.041512              -0.041149
# CASTHMA_CrudePrev                  -0.033386              -0.054615
# CHD_CrudePrev                      -0.005796               0.005901
# CHECKUP_CrudePrev                  -0.079182              -0.075985
# CHOLSCREEN_CrudePrev               -0.048489              -0.039481
# COLON_SCREEN_CrudePrev             -0.078268              -0.092338
# COPD_CrudePrev                     -0.015792              -0.014558
# COREM_CrudePrev                    -0.073395              -0.076517
# COREW_CrudePrev                    -0.057170              -0.063490
# CSMOKING_CrudePrev                 -0.004589              -0.008370
# DENTAL_CrudePrev                   -0.064439              -0.070952
# DIABETES_CrudePrev                  0.014432               0.032896
# HIGHCHOL_CrudePrev                  0.001291               0.013549
# KIDNEY_CrudePrev                    0.012242               0.021834
# LPA_CrudePrev                       0.021049               0.038804
# MAMMOUSE_CrudePrev                 -0.060202              -0.062721
# MHLTH_CrudePrev                     0.033155               0.030303
# OBESITY_CrudePrev                   0.005543               0.019832
# PAPTEST_CrudePrev                  -0.047487              -0.052589
# PHLTH_CrudePrev                     0.038468               0.045480
# SLEEP_CrudePrev                     0.006140              -0.005823
# STROKE_CrudePrev                   -0.014371              -0.009863
# TEETHLOST_CrudePrev                 0.019592               0.018227
# Geolocation                              NaN                    NaN
# OHU2010                             0.037037               0.041178
# PovertyRate                         0.000647               0.009783
# MedianFamilyIncome                 -0.041866              -0.044937
# TractKids                           0.151374               0.157070
# TractSeniors                        0.004447               0.012816
# TractWhite                          0.052143               0.079859
# TractBlack                         -0.017320              -0.024436
# TractAsian                          0.027763               0.011376
# TractNHOPI                          0.025737               0.006144
# TractAIAN                           0.088936               0.070075
# TractOMultir                        0.200304               0.171346
# TractHispanic                       0.187047               0.222661
# TractHUNV                          -0.030181              -0.029543
# TractSNAP                           0.041002               0.053727
# target                              0.020649               0.028562
# Percent_TractWhite                  0.559875               0.586850
# Percent_TractBlack                  0.414823               0.339941
# Percent_TractAsian                  0.438517               0.369069
# Percent_TractNHOPI                  0.400572               0.288935
# Percent_TractAIAN                   0.393191               0.327163
# Percent_TractOMultir                1.000000               0.888169
# Percent_TractHispanic               0.888169               1.000000
#
# [56 rows x 56 columns]

# %%
#calculates the correlation matrix of numeric columns in the DataFrame 
#numeric_only=True ensures that only numeric columns are considered in the correlation calculation
#abs() takes the absolute values of all correlation coefficients
correlations = df.corr(numeric_only=True).abs()

# %%
upper = correlations.where(np.triu(np.ones(correlations.shape), k=1).astype('bool'))
potential_drop = [column for column in upper.columns if any(upper[column] > .90)]

# %%
potential_drop
# Out:
# ['COPD_CrudePrev',
#  'DENTAL_CrudePrev',
#  'KIDNEY_CrudePrev',
#  'MHLTH_CrudePrev',
#  'PHLTH_CrudePrev',
#  'STROKE_CrudePrev',
#  'TEETHLOST_CrudePrev']

# %%
abs(combined_data[potential_drop].corr())
# Out:
#                      COPD_CrudePrev  DENTAL_CrudePrev  KIDNEY_CrudePrev  \
# COPD_CrudePrev             1.000000          0.640983          0.861767
# DENTAL_CrudePrev           0.640983          1.000000          0.682947
# KIDNEY_CrudePrev           0.861767          0.682947          1.000000
# MHLTH_CrudePrev            0.689705          0.883030          0.586595
# PHLTH_CrudePrev            0.896384          0.851759          0.900136
# STROKE_CrudePrev           0.901332          0.643654          0.962226
# TEETHLOST_CrudePrev        0.793277          0.909600          0.756180
#
#                      MHLTH_CrudePrev  PHLTH_CrudePrev  STROKE_CrudePrev  \
# COPD_CrudePrev              0.689705         0.896384          0.901332
# DENTAL_CrudePrev            0.883030         0.851759          0.643654
# KIDNEY_CrudePrev            0.586595         0.900136          0.962226
# MHLTH_CrudePrev             1.000000         0.830011          0.585734
# PHLTH_CrudePrev             0.830011         1.000000          0.869542
# STROKE_CrudePrev            0.585734         0.869542          1.000000
# TEETHLOST_CrudePrev         0.910227         0.893357          0.770638
#
#                      TEETHLOST_CrudePrev
# COPD_CrudePrev                  0.793277
# DENTAL_CrudePrev                0.909600
# KIDNEY_CrudePrev                0.756180
# MHLTH_CrudePrev                 0.910227
# PHLTH_CrudePrev                 0.893357
# STROKE_CrudePrev                0.770638
# TEETHLOST_CrudePrev             1.000000

# %%
# Extracting latitude and longitude from Geolocation
df['Latitude'] = df['Geolocation'].str.split(', ').str[0]
df['Longitude'] = df['Geolocation'].str.split(', ').str[1]

# %%
# Combining related features
df['Mean_PREV'] = df[['ACCESS2_CrudePrev', 'ARTHRITIS_CrudePrev', 'BINGE_CrudePrev']].mean(axis=1)
df['Mean_PREV']
# Out:
# TractFIPS
# 1073000100     21.966667
# 1073000300     23.800000
# 1073000400     22.200000
# 1073000500     23.100000
# 1073000700     24.300000
#                  ...
# 56021001401    18.500000
# 56021001402    18.666667
# 56021001501    18.300000
# 56021001502    19.266667
# 56021002000    18.533333
# Name: Mean_PREV, Length: 27210, dtype: float64

# %%
# Calculating population density
df['PopulationDensity'] = df['Population2010'] / (df['TractWhite'] + df['TractBlack'] + df['TractAsian'])
df['PopulationDensity']
# Out:
# TractFIPS
# 1073000100     1.035046
# 1073000300     1.220437
# 1073000400     1.045412
# 1073000500     1.034682
# 1073000700     1.010192
#                  ...
# 56021001401    1.064785
# 56021001402    0.810593
# 56021001501    0.746619
# 56021001502    1.014141
# 56021002000    0.031342
# Name: PopulationDensity, Length: 27210, dtype: float64

# %%
# Creating age group features
df['Percent_Kids'] = df['TractKids'] / df['Population2010']
df['Percent_Seniors'] = df['TractSeniors'] / df['Population2010']

# %%
df['Percent_Seniors']
# Out:
# TractFIPS
# 1073000100     0.075937
# 1073000300     0.072029
# 1073000400     0.095267
# 1073000500     0.145601
# 1073000700     0.126504
#                  ...
# 56021001401    0.108811
# 56021001402    0.289597
# 56021001501    0.183273
# 56021001502    0.151394
# 56021002000    4.014019
# Name: Percent_Seniors, Length: 27210, dtype: float64

# %%
df['Percent_Kids']
# Out:
# TractFIPS
# 1073000100     0.313281
# 1073000300     0.255210
# 1073000400     0.271120
# 1073000500     0.226257
# 1073000700     0.346139
#                  ...
# 56021001401    0.269376
# 56021001402    0.278097
# 56021001501    0.356582
# 56021001502    0.283975
# 56021002000    8.677570
# Name: Percent_Kids, Length: 27210, dtype: float64

# %%
# Creating income-related features
df['PovertyRate_Percentage'] = df['PovertyRate'] * 100
df['MedianFamilyIncome_Log'] = np.log(df['MedianFamilyIncome'])

# %%
# Urban/Rural Classification
df['Urban'] = (df['OHU2010'] > 1000).astype(int)  # threshold of 1000 housing units for urban classification

# %%
# Health Disparities
df['HealthDisparity_Black_White'] = df['TractBlack'] - df['TractWhite']

# %%
# Healthcare Accessibility
df['HealthcareAccessibility'] = df['ACCESS2_CrudePrev'] / df['TractHUNV']

# %%
# Display the updated DataFrame
df.head()
# Out:
#            StateAbbr   PlaceName  PlaceFIPS        Place_TractID  \
# TractFIPS
# 1073000100        AL  Birmingham     107000  0107000-01073000100
# 1073000300        AL  Birmingham     107000  0107000-01073000300
# 1073000400        AL  Birmingham     107000  0107000-01073000400
# 1073000500        AL  Birmingham     107000  0107000-01073000500
# 1073000700        AL  Birmingham     107000  0107000-01073000700
#
#             Population2010  ACCESS2_CrudePrev  ARTHRITIS_CrudePrev  \
# TractFIPS
# 1073000100            3042               24.4                 31.2
# 1073000300            2735               30.4                 30.5
# 1073000400            3338               24.7                 31.5
# 1073000500            2864               25.2                 35.0
# 1073000700            2577               29.0                 36.3
#
#             BINGE_CrudePrev  BPHIGH_CrudePrev  BPMED_CrudePrev  ...  \
# TractFIPS                                                       ...
# 1073000100             10.3              47.7             77.8  ...
# 1073000300             10.5              48.2             78.5  ...
# 1073000400             10.4              49.1             79.4  ...
# 1073000500              9.1              54.1             82.1  ...
# 1073000700              7.6              56.5             81.8  ...
#
#                   Longitude  Mean_PREV  PopulationDensity  Percent_Kids  \
# TractFIPS
# 1073000100  -86.7228323926)  21.966667           1.035046      0.313281
# 1073000300  -86.7524339780)  23.800000           1.220437      0.255210
# 1073000400  -86.7640474064)  22.200000           1.045412      0.271120
# 1073000500  -86.7749130719)  23.100000           1.034682      0.226257
# 1073000700  -86.8016893706)  24.300000           1.010192      0.346139
#
#             Percent_Seniors  PovertyRate_Percentage  MedianFamilyIncome_Log  \
# TractFIPS
# 1073000100         0.075937             3974.557865               10.376829
# 1073000300         0.072029             4702.534920                9.900884
# 1073000400         0.095267             3263.684520               10.423144
# 1073000500         0.145601             3036.614041               10.572521
# 1073000700         0.126504             5907.434402                9.649240
#
#             Urban  HealthDisparity_Black_White  HealthcareAccessibility
# TractFIPS
# 1073000100      1                       1854.0                 0.107489
# 1073000300      1                       1212.0                 0.157513
# 1073000400      1                       2671.0                 0.120488
# 1073000500      1                       2601.0                 0.065969
# 1073000700      0                       2526.0                 0.117886
#
# [5 rows x 67 columns]

# %%
df.to_csv('../csv_data/final_df.csv')

# %%
df.columns
# Out:
# Index(['StateAbbr', 'PlaceName', 'PlaceFIPS', 'Place_TractID',
#        'Population2010', 'ACCESS2_CrudePrev', 'ARTHRITIS_CrudePrev',
#        'BINGE_CrudePrev', 'BPHIGH_CrudePrev', 'BPMED_CrudePrev',
#        'CANCER_CrudePrev', 'CASTHMA_CrudePrev', 'CHD_CrudePrev',
#        'CHECKUP_CrudePrev', 'CHOLSCREEN_CrudePrev', 'COLON_SCREEN_CrudePrev',
#        'COPD_CrudePrev', 'COREM_CrudePrev', 'COREW_CrudePrev',
#        'CSMOKING_CrudePrev', 'DENTAL_CrudePrev', 'DIABETES_CrudePrev',
#        'HIGHCHOL_CrudePrev', 'KIDNEY_CrudePrev', 'LPA_CrudePrev',
#        'MAMMOUSE_CrudePrev', 'MHLTH_CrudePrev', 'OBESITY_CrudePrev',
#        'PAPTEST_CrudePrev', 'PHLTH_CrudePrev', 'SLEEP_CrudePrev',
#        'STROKE_CrudePrev', 'TEETHLOST_CrudePrev', 'Geolocation', 'OHU2010',
#        'PovertyRate', 'MedianFamilyIncome', 'TractKids', 'TractSeniors',
#        'TractWhite', 'TractBlack', 'TractAsian', 'TractNHOPI', 'TractAIAN',
#        'TractOMultir', 'TractHispanic', 'TractHUNV', 'TractSNAP', 'target',
#        'Percent_TractWhite', 'Percent_TractBlack', 'Percent_TractAsian',
#        'Percent_TractNHOPI', 'Percent_TractAIAN', 'Percent_TractOMultir',
#        'Percent_TractHispanic', 'Latitude', 'Longitude', 'Mean_PREV',
#        'PopulationDensity', 'Percent_Kids', 'Percent_Seniors',
#        'PovertyRate_Percentage', 'MedianFamilyIncome_Log', 'Urban',
#        'HealthDisparity_Black_White', 'HealthcareAccessibility'],
#       dtype='object')

# %%
# Before Feature Engineering

# %%
X = combined_data.drop(columns=['StateAbbr', 'PlaceName', 'PlaceFIPS', 'Place_TractID', 'target'])

# %%
test = combined_data.sample(n=500)
plt.figure(figsize=(20,20))
for i, val in enumerate(X.columns):
    plt.subplot(9, 5, i+1)
    plt.scatter(test[val], test.target)
    plt.title(val)
    plt.tight_layout()
    
plt.show();
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[66], line 4
#       2 plt.figure(figsize=(20,20))
#       3 for i, val in enumerate(X.columns):
# ----> 4     plt.subplot(9, 5, i+1)
#       5     plt.scatter(test[val], test.target)
#       6     plt.title(val)
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:1425, in subplot(*args, **kwargs)
#    1422 fig = gcf()
#    1424 # First, search for an existing subplot with a matching spec.
# -> 1425 key = SubplotSpec._from_subplot_args(fig, args)
#    1427 for ax in fig.axes:
#    1428     # If we found an Axes at the position, we can re-use it if the user passed no
#    1429     # kwargs or if the axes class and kwargs are identical.
#    1430     if (ax.get_subplotspec() == key
#    1431         and (kwargs == {}
#    1432              or (ax._projection_init
#    1433                  == fig._process_projection_requirements(**kwargs)))):
#
# File /opt/anaconda3/lib/python3.11/site-packages/matplotlib/gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 45, not 46

# %%
# Summary statistics
print(combined_data.describe())

# Distribution of key features
for column in ['Population2010', 'PovertyRate', 'MedianFamilyIncome']:
    sns.histplot(combined_data[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.show()
# Out:
#           PlaceFIPS  Population2010  ACCESS2_CrudePrev  ARTHRITIS_CrudePrev  \
# count  2.721000e+04    27210.000000       27209.000000         27210.000000
# mean   2.605539e+06     3785.703087          16.990915            21.430129
# std    1.681206e+06     1944.825182           8.869361             5.995361
# min    1.500300e+04       50.000000           2.400000             2.400000
# 25%    6.815540e+05     2457.250000          10.300000            17.300000
# 50%    2.622000e+06     3611.000000          15.000000            21.000000
# 75%    4.052500e+06     4900.000000          21.600000            25.100000
# max    5.613900e+06    28960.000000          57.800000            58.400000
#
#        BINGE_CrudePrev  BPHIGH_CrudePrev  BPMED_CrudePrev  CANCER_CrudePrev  \
# count     27210.000000      27210.000000     27210.000000      27210.000000
# mean         18.066953         30.653208        70.744274          5.648912
# std           4.032559          8.260472         7.927116          1.803257
# min           2.800000          5.300000         9.600000          0.700000
# 25%          15.500000         25.300000        66.700000          4.500000
# 50%          17.800000         29.500000        71.700000          5.500000
# 75%          20.300000         34.900000        75.900000          6.600000
# max          44.100000         70.300000        92.800000         22.900000
#
#        CASTHMA_CrudePrev  CHD_CrudePrev  ...  Percent_TractHispanic  \
# count       27210.000000   27210.000000  ...           27209.000000
# mean            9.741352       5.602977  ...              45.120996
# std             1.710538       2.118858  ...             246.263607
# min             5.600000       0.300000  ...               0.000000
# 25%             8.500000       4.200000  ...               5.595353
# 50%             9.400000       5.300000  ...              14.704256
# 75%            10.700000       6.700000  ...              40.084388
# max            17.800000      35.800000  ...           13460.937500
#
#           Mean_PREV  PopulationDensity  Percent_Kids  Percent_Seniors  \
# count  27210.000000       27209.000000  27209.000000     27209.000000
# mean      18.829440           1.115108      0.489007         0.225892
# std        2.898605           0.358034      1.962853         0.847112
# min        9.200000           0.004965      0.000000         0.000000
# 25%       16.766667           1.033481      0.197751         0.075179
# 50%       18.500000           1.085202      0.249279         0.110792
# 75%       20.566667           1.223881      0.306868         0.159019
# max       32.000000          11.490683     88.051724        36.313725
#
#        PovertyRate_Percentage  MedianFamilyIncome_Log         Urban  \
# count            27209.000000            26897.000000  27210.000000
# mean              1834.936371               11.088799      0.776883
# std               1371.891178                0.531467      0.416343
# min                  0.000000                7.823646      0.000000
# 25%                763.082491               10.710298      1.000000
# 50%               1485.227575               11.090935      1.000000
# 75%               2602.935181               11.469120      1.000000
# max              10000.000000               12.429220      1.000000
#
#        HealthDisparity_Black_White  HealthcareAccessibility
# count                 27209.000000             2.720800e+04
# mean                  -1728.794811                      inf
# std                    2283.587546                      NaN
# min                  -21930.000000             9.216590e-04
# 25%                   -3098.000000             6.305688e-02
# 50%                   -1898.000000             1.327659e-01
# 75%                    -561.000000             3.009630e-01
# max                   11744.000000                      inf
#
# [8 rows x 61 columns]
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Set the style of the plots
sns.set_style("darkgrid")

# Visualization 1: Distribution of Median Family Income across Counties
plt.figure(figsize=(12, 6))
sns.histplot(combined_data['MedianFamilyIncome'], bins=30, kde=True, color='Green')
plt.title('Distribution of Median Family Income Across Counties')
plt.xlabel('Median Family Income')
plt.ylabel('Number of Counties')
plt.axvline(combined_data['MedianFamilyIncome'].mean(), color='red', linestyle='--', label='Mean Income')
plt.legend()
plt.savefig('../Images/Distribution of Median Family Income Across Counties.png', dpi=200, bbox_inches='tight')

plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
