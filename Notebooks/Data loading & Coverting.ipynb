# %% [markdown]
# ## Data Loading and Formating files

# %%
#imports
import pandas as pd

# %% [markdown]
# ## Food Access Data
# - Read the data
# - Save the data to csv file

# %%
#reading file
df = pd.ExcelFile('../Data/FoodAccessResearchAtlasData2019.xlsx')

# %%
sheet_names = df.sheet_names

# %%
sheet_names
# Out:
# ['Read Me', 'Variable Lookup', 'Food Access Research Atlas']

# %%
food_data = df.parse(2)

# %%
food_data.head()
# Out:
#    CensusTract    State          County  Urban  Pop2010  OHU2010  \
# 0   1001020100  Alabama  Autauga County      1     1912      693
# 1   1001020200  Alabama  Autauga County      1     2170      743
# 2   1001020300  Alabama  Autauga County      1     3373     1256
# 3   1001020400  Alabama  Autauga County      1     4386     1722
# 4   1001020500  Alabama  Autauga County      1    10766     4082
#
#    GroupQuartersFlag  NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  \
# 0                  0       0.0  0.000000                  0  ...
# 1                  0     181.0  8.341014                  1  ...
# 2                  0       0.0  0.000000                  0  ...
# 3                  0       0.0  0.000000                  0  ...
# 4                  0     181.0  1.681219                  0  ...
#
#    TractSeniors  TractWhite  TractBlack  TractAsian  TractNHOPI  TractAIAN  \
# 0         221.0      1622.0       217.0        14.0         0.0       14.0
# ...

# %%
#shape of the data
food_data.shape
# Out:
# (72531, 147)

# %%
#summary of the data
food_data.describe()
# Out:
#         CensusTract         Urban       Pop2010       OHU2010  \
# count  7.253100e+04  72531.000000  72531.000000  72531.000000
# mean   2.782573e+10      0.760626   4256.739022   1609.191821
# std    1.581647e+10      0.426704   1955.987626    725.676046
# min    1.001020e+09      0.000000      1.000000      0.000000
# 25%    1.212708e+10      1.000000   2899.000000   1108.000000
# 50%    2.712979e+10      1.000000   4011.000000   1525.000000
# 75%    4.103900e+10      1.000000   5330.500000   2021.000000
# max    5.604595e+10      1.000000  37452.000000  16043.000000
#
#        GroupQuartersFlag      NUMGQTRS      PCTGQTRS  LILATracts_1And10  \
# count       72531.000000  72506.000000  72506.000000       72531.000000
# mean            0.007114    110.121549      2.708678           0.128125
# std             0.084046    443.931753      9.570881           0.334231
# min             0.000000      0.000000      0.000000           0.000000
# ...

# %%
#saving to csv file as it was in xslx
food_data.to_csv('../csv_data/food_access_data.csv', index=False)

# %% [markdown]
# ## Health Global

# %%
health_global = pd.read_csv('../Data/500_Cities__View_a_city_s_census_tract_data__GIS_friendly_data_.csv')

# %%
health_global.head()
# Out:
#   StateAbbr   PlaceName  PlaceFIPS   TractFIPS        Place_TractID  \
# 0        AL  Birmingham     107000  1073000100  0107000-01073000100
# 1        AL  Birmingham     107000  1073000300  0107000-01073000300
# 2        AL  Birmingham     107000  1073000400  0107000-01073000400
# 3        AL  Birmingham     107000  1073000500  0107000-01073000500
# 4        AL  Birmingham     107000  1073000700  0107000-01073000700
#
#    Population2010  ACCESS2_CrudePrev ACCESS2_Crude95CI  ARTHRITIS_CrudePrev  \
# 0            3042               24.4      (21.2, 27.8)                 31.2
# 1            2735               30.4      (27.1, 33.7)                 30.5
# 2            3338               24.7      (21.1, 28.5)                 31.5
# 3            2864               25.2      (21.6, 29.0)                 35.0
# 4            2577               29.0      (24.5, 33.8)                 36.3
#
#   ARTHRITIS_Crude95CI  ...  PAPTEST_Crude95CI PHLTH_CrudePrev  \
# ...

# %%
health_global.to_csv('../csv_data/public_health.csv')

# %%
health_global.shape
# Out:
# (27210, 63)

# %% [markdown]
# ## Grocery data

# %%
grocery_stores = pd.read_csv('../csv_data/Grocery_Stores.csv')

# %%
grocery_stores.head()
# Out:
#                                    the_geom  OBJECTID           Business Name  \
# 0  POINT (-90.010462442348 30.011375732797)        62           CHEF FUEL LLC
# 1  POINT (-90.064471472745 29.956657578922)        28  BIG EASY MARDI GRAS CO
# 2  POINT (-90.076989294557 29.951922709288)        73           COURT LIQUORS
# 3  POINT (-90.082568661226 29.942860681516)       212   PROJECT FOOD STORE #2
# 4  POINT (-90.110647659927 29.967936655128)        72   COSTCO WHOLESALE 1147
#
#                            Address Suite    Zip  Phone Number
# 0            6711 CHEF MENTEUR HWY   NaN  70126           NaN
# 1                  600 CHARTRES ST   NaN  70130  504-524-4729
# 2               618-620 BOURBON ST   NaN  70130  504-581-5804
# 3  2238 MARTIN LUTHER KING JR BLVD   NaN  70113  504-586-1762
# 4                   3900 DUBLIN ST   NaN  70118  425-313-8100

# %%
grocery_stores.shape
# Out:
# (310, 7)

# %%
consumer = pd.ExcelFile('../Data/consumer_exp.xlsx')
consumer_df = consumer.parse(consumer.sheet_names[0])  #read the first sheet

# Display the first few rows of the DataFrame
print(consumer_df.head())
# Out:
#   Table 3113. Midwestern region by income before taxes: Average annual expenditures and characteristics, Consumer Expenditure Survey, 2016-2017  \
# 0                                                NaN
# 1                                               Item
# 2            Number of consumer units (in thousands)
# 3                                                NaN
# 4                     Consumer unit characteristics:
#
#        Unnamed: 1          Unnamed: 2          Unnamed: 3  \
# 0             NaN                 NaN                 NaN
# 1  Total\nmidwest  Less\nthan\n$5,000  $5,000\nto\n$9,999
# 2           27896                1044                 881
# 3             NaN                 NaN                 NaN
# 4             NaN                 NaN                 NaN
#
#              Unnamed: 4            Unnamed: 5            Unnamed: 6  \
# 0                   NaN                   NaN                   NaN
# ...

# %% [markdown]
# ### Extracting food data dictionary

# %%
#Food data dictionary
hd = pd.ExcelFile('../Data/FoodAccessResearchAtlasData2019.xlsx')

# %%
sheet_names = hd.sheet_names

# %%
sheet_names
# Out:
# ['Read Me', 'Variable Lookup', 'Food Access Research Atlas']

# %%
import pandas as pd

# Specify the path to your Excel file
excel_file_path = '../Data/FoodAccessResearchAtlasData2019.xlsx'

# Read the "Variable Lookup" sheet into a DataFrame
variable_lookup_df = pd.read_excel(excel_file_path, sheet_name='Variable Lookup')

# Display the first few rows of the DataFrame to verify the data
variable_lookup_df
# Out:
#              Field                                           LongName  \
# 0      CensusTract                                       Census tract
# 1            State                                              State
# 2           County                                             County
# 3            Urban                                        Urban tract
# 4          POP2010                            Population, tract total
# ..             ...                                                ...
# 142      TractAIAN  Tract American Indian and Alaska Native popula...
# 143   TractOMultir       Tract Other/Multiple race population, number
# 144  TractHispanic        Tract Hispanic or Latino population, number
# 145      TractHUNV      Tract housing units without a vehicle, number
# 146      TractSNAP  Tract housing units receiving SNAP benefits, n...
#
#                                            Description
# 0                                  Census tract number
# ...

# %%
variable_lookup_df.to_csv('../csv_data/food_data_dictionary.csv')

# %%
variable_lookup_df.shape
# Out:
# (147, 3)
